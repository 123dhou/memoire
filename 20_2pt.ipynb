# %% [markdown]
# Importation des bibliothèques nécessaires

# %%
import random
import math
import matplotlib.pyplot as plt
import itertools
import numpy as np

# %% [markdown]
# Fonction pour générer des valeurs aléatoires

# %%
def generate_random(x):
  test = []
  for _ in range(x):
    random_number = random.randint(1, 20) # genere des nums entre 1 et 20
    test.append(random_number)
  return test

# %% [markdown]
# Fonction pour générer des valeurs aléatoires

# %%
def generate_random_client(x):
    test = []
    while len(test) < x:
        random_number = random.randint(1, 20)
        if random_number not in test:
            test.append(random_number)
    return test

# %% [markdown]
# Fonction pour générer la population avec un taille donnée

# %%
def generate_population(clients, population_size):
    population = []
    for _ in range(population_size):
        random.shuffle(clients)  # Mélange aléatoire des coordonnées des clients
        population.append(list(clients))  # Ajout d'un individu à la population
    return population

# %% [markdown]
# Fonction pour calculer la distance entre paires de clients

# %%
def calculate_distance(x1, y1, x2, y2):
    return math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

# %% [markdown]
# Fonction pour calculer la matrice de distance entre les clients

# %%
def calculate_distance_matrix(client_coordinates):
    num_clients = len(client_coordinates)
    distance_matrix = [[0] * num_clients for _ in range(num_clients)]

    for i in range(num_clients):
        for j in range(num_clients):
            if i != j:
                x1, y1 = client_coordinates[i]
                x2, y2 = client_coordinates[j]
                distance = calculate_distance(x1, y1, x2, y2)
                distance_matrix[i][j] = distance

    return distance_matrix

# %% [markdown]
# Fonction pour calculer la matrice de distance de la consommation d'énergie

# %%
def calculate_energy_consumption(speed, consumption_rate, distance_matrix):
    energy_matrix = []

    for i in range(len(distance_matrix)):
        energy_row = [distance * consumption_rate / speed for distance in distance_matrix[i]]
        energy_matrix.append(energy_row)

    return energy_matrix

# %% [markdown]
# Evaluation de la population

# %%
def evaluate_population(client_coordinates, speed, consumption_rate, population):
    distances = []
    energies = []
    fitness_scores = []

    distance_matrix = calculate_distance_matrix(client_coordinates)
    energy_matrix = calculate_energy_consumption(speed, consumption_rate, distance_matrix)

    for individual in population:

        energy = sum(energy_matrix[i][j] for i, j in zip(individual[:-1], individual[1:]))
        fitness_score = 1/(energy)
        energies.append(energy)
        fitness_scores.append(fitness_score)

    return  energies, fitness_scores

# %% [markdown]
# Evaluation de chaque individu (fitness score)

# %%
def evaluate_fitness(individual, client_coordinates, speed, consumption_rate):

    distance_matrix = calculate_distance_matrix(client_coordinates)
    energy_matrix = calculate_energy_consumption(speed, consumption_rate, distance_matrix)


    energy = sum(energy_matrix[individual[i]][individual[i+1]] for i in range(len(individual) - 1))

    # Fitness score is a combination of distance and energy
    fitness_score = 1/(energy)

    return fitness_score

# %% [markdown]
# Séléctionner les parents

# %%
def select_parents(population, num_parents):
    parents = random.sample(population, num_parents)
    return parents

# %% [markdown]
# croisement des meilleurs parents pour générer les child (croisement avec deux points aléatoires)

# %%
import time
def crossover(parents, crossover_rate):
    start_time = time.time()
    num_parents = len(parents)
    num_genes = len(parents[0])  # Nombre de gènes dans chaque parent

    children = []

    for i in range(num_parents):
        parent1 = parents[i]
        parent2 = parents[(i + 1) % num_parents]  # Sélection du parent suivant pour assurer une boucle

        if random.random() > crossover_rate:
            children.append(parent1)
            continue

        # Création d'un tableau vide pour stocker les gènes déjà utilisés
        used_genes = set()

        # Génération de deux points de coupure uniques
        point1, point2 = sorted(random.sample(range(1, num_genes - 1), 2))

        # Création de l'enfant en préservant l'ordre des gènes de parent1 et en ajoutant les gènes de parent2
        child = []
        for gene in parent1[:point1]:
            child.append(gene)
            used_genes.add(gene)

        for gene in parent2:
            if gene not in used_genes:
                child.append(gene)
                used_genes.add(gene)

        for gene in parent1[point2:]:
            if gene not in used_genes:
                child.append(gene)
                used_genes.add(gene)

        children.append(child)
    end_time = time.time()
    execution_time = (end_time - start_time) * 1000  # Convertir en millisecondes
    print("Temps d'exécution de crossover:", execution_time, "millisecondes")
    return children

# %% [markdown]
# Fonction de mutation qui permet de changer les position des gènes trouver dans child de manière aléatoire

# %%
def mutation(children, mutation_rate):
    mutated_children = []

    for child in children:
        if random.random() <= mutation_rate:
            mutated_child = list(child)  # Convertir en une liste modifiable

            # Générer deux positions de gènes uniques
            gene_pos1, gene_pos2 = random.sample(range(len(child)), 2)

            # Échanger les positions des gènes
            mutated_child[gene_pos1], mutated_child[gene_pos2] = mutated_child[gene_pos2], mutated_child[gene_pos1]

            mutated_children.append(mutated_child)
        else:
            mutated_children.append(child)

    return mutated_children

# %% [markdown]
# Données (paramètres d'entrées)

# %%
clients = generate_random_client(20) # les indices des clients
population_size = 50 # taille de la population
client_coordinates= {0: (0, 0), 1: (54, 22), 2: (21, 34), 3: (64, 62), 4: (78, 96), 5: (54, 22), 6: (35, 45), 7: (12, 50), 8: (38, 1), 9: (49, 69), 10: (19, 5), 11: (91, 12), 12: (91, 10), 13: (92, 29), 15: (26, 0), 14: (72, 53), 16: (8, 32), 17: (79, 7), 18: (45, 58),  19: (54, 90), 20: (70, 35)}
demands = [20, 18, 9, 12, 22, 13, 10, 14, 33, 27, 24, 2, 19, 38, 10, 56, 17, 1, 5, 11] # les demandes des clients
capacity = (2/3) * sum (demands) # capacité maximale
num_parents = 2 # nombre de parents choisi
crossover_rate = 0.8 # taux de croisement
mutation_rate = 0.2 # taux de mutation
num_generations = 100 # nombre de génération
k = 4 # nombre de véhicules
speed = 80 # vitesse
consumption_rate = 0.1  # consommation spécifique en kWh/km

# %%
population = generate_population(clients, population_size)
# Afficher chaque individu
for individual in population:
    print(individual)

distance_matrix = calculate_distance_matrix(client_coordinates)
for row in distance_matrix:
  print(row)

energy_matrix = calculate_energy_consumption(speed, consumption_rate, distance_matrix)
for row in energy_matrix:
  print(row)

energies, fitness_scores = evaluate_population(client_coordinates, speed, consumption_rate, population)

for i in range(len(population)):
    print(f"Individu {i+1} -  Consommation d'énergie : {energies[i]}, Fitness Score : {fitness_scores[i]}")

parents = select_parents(population, num_parents)
for parent in parents:
    print("Parent:", parent )

children  = crossover(parents, crossover_rate)
for child in children:
    print("child:", child)

mutated_children = mutation(children, mutation_rate)
for child_mutate in mutated_children:
  print("child mutate:", child_mutate)
# Out:
# [5, 4, 1, 3, 19, 6, 12, 16, 8, 2, 13, 10, 20, 9, 18, 14, 17, 15, 11, 7]
# [12, 11, 7, 1, 17, 3, 15, 8, 20, 14, 5, 18, 6, 19, 10, 16, 4, 2, 13, 9]
# [16, 1, 4, 2, 15, 3, 19, 11, 17, 13, 7, 5, 12, 9, 8, 20, 10, 14, 18, 6]
# [16, 10, 17, 13, 18, 19, 14, 8, 6, 12, 2, 15, 4, 7, 3, 9, 20, 11, 1, 5]
# [10, 17, 6, 5, 15, 7, 9, 13, 3, 14, 20, 18, 12, 2, 1, 11, 19, 4, 8, 16]
# [7, 6, 9, 12, 20, 18, 15, 2, 1, 17, 8, 14, 3, 13, 16, 5, 10, 11, 19, 4]
# [11, 13, 12, 20, 6, 15, 3, 8, 7, 17, 1, 10, 14, 16, 18, 9, 5, 2, 19, 4]
# [13, 12, 9, 14, 20, 17, 5, 8, 2, 4, 16, 11, 15, 3, 1, 10, 19, 6, 7, 18]
# [11, 1, 2, 20, 19, 4, 7, 8, 14, 12, 16, 9, 18, 17, 6, 10, 5, 15, 3, 13]
# [17, 10, 13, 8, 16, 7, 20, 3, 5, 6, 15, 14, 4, 18, 2, 12, 11, 19, 9, 1]
# [2, 10, 4, 18, 19, 17, 5, 8, 13, 6, 12, 14, 16, 15, 9, 1, 11, 7, 3, 20]
# [20, 15, 17, 8, 18, 10, 6, 5, 3, 12, 7, 16, 13, 11, 4, 2, 9, 14, 1, 19]
# [14, 3, 6, 20, 5, 7, 13, 16, 10, 9, 15, 1, 11, 2, 19, 4, 8, 12, 17, 18]
# [15, 2, 5, 18, 13, 9, 14, 10, 1, 11, 19, 3, 6, 20, 16, 12, 17, 4, 8, 7]
# [7, 14, 11, 17, 8, 4, 1, 9, 15, 6, 19, 10, 2, 20, 12, 16, 18, 3, 5, 13]
# [14, 1, 16, 12, 4, 18, 20, 19, 17, 2, 7, 5, 15, 9, 13, 11, 8, 10, 6, 3]
# [11, 4, 5, 10, 15, 13, 9, 3, 8, 7, 1, 20, 6, 14, 18, 16, 2, 19, 17, 12]
# [19, 17, 20, 9, 12, 1, 14, 2, 4, 16, 11, 8, 6, 13, 3, 5, 10, 15, 7, 18]
# [10, 7, 17, 2, 16, 14, 13, 5, 15, 20, 9, 1, 18, 11, 6, 19, 12, 8, 4, 3]
# [6, 10, 9, 5, 7, 15, 12, 14, 17, 3, 13, 11, 18, 20, 16, 19, 2, 8, 1, 4]
# [4, 3, 11, 7, 6, 15, 14, 9, 10, 12, 19, 17, 1, 16, 8, 13, 2, 18, 5, 20]
# [8, 10, 4, 20, 14, 5, 17, 3, 7, 12, 16, 11, 18, 9, 6, 15, 13, 2, 1, 19]
# [11, 10, 6, 14, 4, 20, 7, 18, 15, 8, 16, 13, 5, 12, 3, 9, 19, 1, 17, 2]
# [9, 10, 12, 20, 18, 14, 1, 8, 13, 3, 16, 5, 4, 2, 6, 15, 7, 11, 17, 19]
# [18, 8, 13, 1, 11, 6, 14, 5, 4, 12, 2, 10, 15, 7, 17, 3, 19, 16, 9, 20]
# [1, 11, 12, 9, 7, 13, 16, 4, 6, 14, 8, 5, 10, 2, 3, 18, 19, 20, 15, 17]
# [12, 15, 17, 1, 8, 16, 7, 11, 13, 18, 4, 9, 10, 5, 19, 6, 20, 3, 14, 2]
# [13, 4, 16, 9, 1, 5, 8, 11, 15, 20, 14, 10, 18, 3, 12, 7, 6, 19, 2, 17]
# [13, 8, 1, 19, 16, 9, 12, 11, 3, 18, 17, 4, 5, 2, 14, 20, 7, 10, 15, 6]
# [16, 12, 11, 1, 14, 20, 3, 15, 6, 8, 5, 2, 17, 10, 13, 7, 18, 19, 9, 4]
# [15, 3, 2, 8, 19, 20, 4, 11, 13, 16, 9, 12, 14, 5, 6, 18, 7, 17, 10, 1]
# [15, 19, 13, 8, 20, 17, 6, 5, 10, 18, 3, 1, 2, 9, 4, 12, 16, 11, 14, 7]
# [20, 10, 12, 11, 19, 3, 1, 16, 15, 14, 6, 18, 9, 2, 13, 8, 17, 5, 4, 7]
# [5, 1, 15, 16, 19, 12, 11, 14, 7, 20, 3, 18, 13, 17, 8, 6, 10, 2, 9, 4]
# [5, 15, 17, 4, 12, 18, 2, 14, 10, 13, 3, 1, 16, 20, 7, 9, 8, 19, 6, 11]
# [14, 4, 17, 16, 19, 11, 18, 3, 9, 13, 15, 12, 2, 5, 20, 6, 10, 8, 1, 7]
# [12, 3, 10, 20, 1, 14, 19, 18, 16, 8, 11, 6, 5, 13, 2, 4, 17, 15, 7, 9]
# [6, 20, 1, 16, 9, 5, 3, 19, 11, 17, 14, 15, 18, 12, 7, 8, 10, 2, 13, 4]
# [7, 15, 10, 16, 6, 5, 18, 19, 8, 2, 14, 3, 4, 11, 12, 20, 9, 1, 17, 13]
# [6, 8, 19, 18, 10, 5, 11, 9, 2, 17, 3, 20, 4, 16, 15, 1, 7, 13, 14, 12]
# [7, 6, 5, 10, 11, 8, 13, 2, 12, 20, 3, 9, 19, 16, 14, 15, 1, 4, 17, 18]
# [7, 19, 16, 20, 4, 2, 5, 10, 11, 17, 14, 15, 1, 3, 9, 8, 6, 12, 18, 13]
# [8, 18, 7, 10, 19, 4, 1, 9, 3, 20, 14, 13, 15, 12, 17, 11, 16, 6, 5, 2]
# [15, 9, 1, 18, 11, 4, 2, 12, 6, 5, 20, 3, 17, 14, 10, 19, 7, 8, 16, 13]
# [7, 18, 4, 10, 9, 20, 11, 16, 12, 6, 13, 14, 2, 5, 3, 15, 19, 1, 8, 17]
# [10, 16, 5, 18, 11, 3, 8, 14, 15, 12, 17, 19, 2, 4, 6, 20, 7, 1, 9, 13]
# [1, 19, 20, 11, 2, 8, 16, 17, 6, 9, 4, 15, 18, 7, 10, 12, 5, 13, 3, 14]
# [12, 9, 3, 11, 8, 19, 17, 10, 4, 1, 18, 5, 2, 7, 20, 16, 13, 15, 6, 14]
# [19, 14, 10, 1, 16, 8, 3, 6, 20, 2, 15, 9, 12, 4, 5, 7, 18, 11, 13, 17]
# [4, 16, 12, 6, 13, 14, 10, 18, 7, 9, 15, 2, 19, 8, 5, 1, 11, 17, 20, 3]
# [0, 58.309518948453004, 39.96248240537617, 89.10667763978185, 123.69316876852982, 58.309518948453004, 57.0087712549569, 51.419840528729765, 38.01315561749642, 84.62860036654276, 19.6468827043885, 91.7877987534291, 91.54780172128658, 96.46242791885346, 89.40357934669059, 26.0, 32.984845004941285, 79.30952023559341, 73.40980860893181, 104.95713410721541, 78.26237921249263]
# [58.309518948453004, 0, 35.11409973215888, 41.23105625617661, 77.79460135510689, 0.0, 29.832867780352597, 50.47771785649585, 26.40075756488817, 47.265209192385896, 38.91015291668744, 38.3275357934736, 38.897300677553446, 38.63935817272331, 35.84689665786984, 35.608987629529715, 47.07440918375928, 29.154759474226502, 37.107950630558946, 68.0, 20.615528128088304]
# [39.96248240537617, 35.11409973215888, 0, 51.31276644267, 84.21995013059554, 35.11409973215888, 17.804493814764857, 18.35755975068582, 37.12142238654117, 44.82186966202994, 29.068883707497267, 73.37574531137656, 74.0, 71.17583859709698, 54.42425929675111, 34.36568055487916, 13.152946437965905, 63.97655820689325, 33.94112549695428, 65.0, 49.01020301937138]
# [89.10667763978185, 41.23105625617661, 51.31276644267, 0, 36.76955262170047, 41.23105625617661, 33.61547262794322, 53.36665625650534, 66.30987860040162, 16.55294535724685, 72.62231062146122, 56.824290580701486, 58.59180830116101, 43.278170016764804, 12.041594578792296, 72.71863585079137, 63.52952069707436, 57.0087712549569, 19.4164878389476, 29.732137494637012, 27.65863337187866]
# [123.69316876852982, 77.79460135510689, 84.21995013059554, 36.76955262170047, 0, 77.79460135510689, 66.70832032063167, 80.44874144447506, 103.07764064044152, 39.6232255123179, 108.45275469069469, 85.0, 86.97700845625813, 68.4470598345904, 43.41658669218482, 109.17875251164945, 94.847245611035, 89.00561780022652, 50.32891812864648, 24.73863375370596, 61.5223536610881]
# [58.309518948453004, 0.0, 35.11409973215888, 41.23105625617661, 77.79460135510689, 0, 29.832867780352597, 50.47771785649585, 26.40075756488817, 47.265209192385896, 38.91015291668744, 38.3275357934736, 38.897300677553446, 38.63935817272331, 35.84689665786984, 35.608987629529715, 47.07440918375928, 29.154759474226502, 37.107950630558946, 68.0, 20.615528128088304]
# [57.0087712549569, 29.832867780352597, 17.804493814764857, 33.61547262794322, 66.70832032063167, 29.832867780352597, 0, 23.53720459187964, 44.10215414239989, 27.784887978899608, 43.08131845707603, 65.0, 66.03786792439622, 59.20304046246274, 37.8549864614954, 45.89117562233506, 29.966648127543394, 58.137767414994535, 16.401219466856727, 48.84669896727925, 36.40054944640259]
# [51.419840528729765, 50.47771785649585, 18.35755975068582, 53.36665625650534, 80.44874144447506, 50.47771785649585, 23.53720459187964, 0, 55.47071299343465, 41.593268686170845, 45.5411901469428, 87.66413177577246, 88.54942122905152, 82.71033792700887, 60.07495318350236, 51.92301994298868, 18.439088914585774, 79.61155694998057, 33.95585369269929, 58.0, 59.90826320300064]
# [38.01315561749642, 26.40075756488817, 37.12142238654117, 66.30987860040162, 103.07764064044152, 26.40075756488817, 44.10215414239989, 55.47071299343465, 0, 68.8839603971781, 19.4164878389476, 54.12947441089743, 53.75872022286245, 60.8276253029822, 62.12889826803627, 12.041594578792296, 43.139309220245984, 41.43669871020132, 57.42821606144492, 90.4267659490264, 46.69047011971501]
# [84.62860036654276, 47.265209192385896, 44.82186966202994, 16.55294535724685, 39.6232255123179, 47.265209192385896, 27.784887978899608, 41.593268686170845, 68.8839603971781, 0, 70.68238818828917, 70.80254232723568, 72.42237223399962, 58.728187440104094, 28.0178514522438, 72.73238618387272, 55.226805085936306, 68.87670143089025, 11.704699910719626, 21.587033144922902, 39.96248240537617]
# [19.6468827043885, 38.91015291668744, 29.068883707497267, 72.62231062146122, 108.45275469069469, 38.91015291668744, 43.08131845707603, 45.5411901469428, 19.4164878389476, 70.68238818828917, 0, 72.3394774656273, 72.17340230306452, 76.84399781375251, 71.50524456289902, 8.602325267042627, 29.154759474226502, 60.03332407921454, 59.033888572581766, 91.92388155425118, 59.16924876994806]
# [91.7877987534291, 38.3275357934736, 73.37574531137656, 56.824290580701486, 85.0, 38.3275357934736, 65.0, 87.66413177577246, 54.12947441089743, 70.80254232723568, 72.3394774656273, 0, 2.0, 17.029386365926403, 45.18849411078001, 66.09841147864296, 85.37564055396598, 13.0, 65.05382386916237, 86.33075929238663, 31.144823004794873]
# [91.54780172128658, 38.897300677553446, 74.0, 58.59180830116101, 86.97700845625813, 38.897300677553446, 66.03786792439622, 88.54942122905152, 53.75872022286245, 72.42237223399962, 72.17340230306452, 2.0, 0, 19.026297590440446, 47.01063709417264, 65.76473218982953, 85.86617494683223, 12.36931687685298, 66.48308055437865, 88.14193099768123, 32.64965543462902]
# [96.46242791885346, 38.63935817272331, 71.17583859709698, 43.278170016764804, 68.4470598345904, 38.63935817272331, 59.20304046246274, 82.71033792700887, 60.8276253029822, 58.728187440104094, 76.84399781375251, 17.029386365926403, 19.026297590440446, 0, 31.240998703626616, 72.09022125087424, 84.0535543567314, 25.553864678361276, 55.226805085936306, 71.8679344353238, 22.80350850198276]
# [89.40357934669059, 35.84689665786984, 54.42425929675111, 12.041594578792296, 43.41658669218482, 35.84689665786984, 37.8549864614954, 60.07495318350236, 62.12889826803627, 28.0178514522438, 71.50524456289902, 45.18849411078001, 47.01063709417264, 31.240998703626616, 0, 70.178344238091, 67.35725647619564, 46.52956049652737, 27.459060435491963, 41.14608122288197, 18.110770276274835]
# [26.0, 35.608987629529715, 34.36568055487916, 72.71863585079137, 109.17875251164945, 35.608987629529715, 45.89117562233506, 51.92301994298868, 12.041594578792296, 72.73238618387272, 8.602325267042627, 66.09841147864296, 65.76473218982953, 72.09022125087424, 70.178344238091, 0, 36.71511950137164, 53.46026561849464, 61.032778078668514, 94.25497334358543, 56.22277118748239]
# [32.984845004941285, 47.07440918375928, 13.152946437965905, 63.52952069707436, 94.847245611035, 47.07440918375928, 29.966648127543394, 18.439088914585774, 43.139309220245984, 55.226805085936306, 29.154759474226502, 85.37564055396598, 85.86617494683223, 84.0535543567314, 67.35725647619564, 36.71511950137164, 0, 75.27283706623525, 45.221676218380054, 74.02702209328699, 62.07253821135398]
# [79.30952023559341, 29.154759474226502, 63.97655820689325, 57.0087712549569, 89.00561780022652, 29.154759474226502, 58.137767414994535, 79.61155694998057, 41.43669871020132, 68.87670143089025, 60.03332407921454, 13.0, 12.36931687685298, 25.553864678361276, 46.52956049652737, 53.46026561849464, 75.27283706623525, 0, 61.29437168288782, 86.68333173107735, 29.410882339705484]
# [73.40980860893181, 37.107950630558946, 33.94112549695428, 19.4164878389476, 50.32891812864648, 37.107950630558946, 16.401219466856727, 33.95585369269929, 57.42821606144492, 11.704699910719626, 59.033888572581766, 65.05382386916237, 66.48308055437865, 55.226805085936306, 27.459060435491963, 61.032778078668514, 45.221676218380054, 61.29437168288782, 0, 33.24154027718932, 33.97057550292606]
# [104.95713410721541, 68.0, 65.0, 29.732137494637012, 24.73863375370596, 68.0, 48.84669896727925, 58.0, 90.4267659490264, 21.587033144922902, 91.92388155425118, 86.33075929238663, 88.14193099768123, 71.8679344353238, 41.14608122288197, 94.25497334358543, 74.02702209328699, 86.68333173107735, 33.24154027718932, 0, 57.28001396647874]
# [78.26237921249263, 20.615528128088304, 49.01020301937138, 27.65863337187866, 61.5223536610881, 20.615528128088304, 36.40054944640259, 59.90826320300064, 46.69047011971501, 39.96248240537617, 59.16924876994806, 31.144823004794873, 32.64965543462902, 22.80350850198276, 18.110770276274835, 56.22277118748239, 62.07253821135398, 29.410882339705484, 33.97057550292606, 57.28001396647874, 0]
# [0.0, 0.07288689868556626, 0.04995310300672022, 0.11138334704972733, 0.15461646096066228, 0.07288689868556626, 0.07126096406869613, 0.0642748006609122, 0.04751644452187053, 0.10578575045817844, 0.024558603380485624, 0.11473474844178637, 0.11443475215160823, 0.12057803489856685, 0.11175447418336323, 0.0325, 0.04123105625617661, 0.09913690029449176, 0.09176226076116477, 0.1311964176340193, 0.0978279740156158]
# [0.07288689868556626, 0.0, 0.043892624665198596, 0.05153882032022076, 0.09724325169388362, 0.0, 0.03729108472544075, 0.06309714732061981, 0.033000946956110215, 0.05908151149048237, 0.048637691145859294, 0.047909419741842, 0.04862162584694181, 0.048299197715904144, 0.0448086208223373, 0.04451123453691215, 0.0588430114796991, 0.03644344934278313, 0.04638493828819869, 0.085, 0.02576941016011038]
# [0.04995310300672022, 0.043892624665198596, 0.0, 0.0641409580533375, 0.10527493766324443, 0.043892624665198596, 0.022255617268456075, 0.022946949688357275, 0.04640177798317646, 0.05602733707753743, 0.036336104634371584, 0.0917196816392207, 0.0925, 0.08896979824637123, 0.06803032412093889, 0.042957100693598954, 0.016441183047457383, 0.07997069775861657, 0.042426406871192854, 0.08125, 0.06126275377421423]
# [0.11138334704972733, 0.05153882032022076, 0.0641409580533375, 0.0, 0.045961940777125586, 0.05153882032022076, 0.04201934078492903, 0.06670832032063168, 0.08288734825050202, 0.02069118169655856, 0.09077788827682653, 0.07103036322587686, 0.07323976037645127, 0.05409771252095601, 0.01505199322349037, 0.09089829481348922, 0.07941190087134295, 0.07126096406869613, 0.0242706097986845, 0.037165171868296265, 0.03457329171484833]
# [0.15461646096066228, 0.09724325169388362, 0.10527493766324443, 0.045961940777125586, 0.0, 0.09724325169388362, 0.0833854004007896, 0.10056092680559384, 0.1288470508005519, 0.04952903189039738, 0.13556594336336839, 0.10625, 0.10872126057032268, 0.08555882479323801, 0.05427073336523103, 0.13647344063956182, 0.11855905701379377, 0.11125702225028315, 0.0629111476608081, 0.030923292192132457, 0.07690294207636013]
# [0.07288689868556626, 0.0, 0.043892624665198596, 0.05153882032022076, 0.09724325169388362, 0.0, 0.03729108472544075, 0.06309714732061981, 0.033000946956110215, 0.05908151149048237, 0.048637691145859294, 0.047909419741842, 0.04862162584694181, 0.048299197715904144, 0.0448086208223373, 0.04451123453691215, 0.0588430114796991, 0.03644344934278313, 0.04638493828819869, 0.085, 0.02576941016011038]
# [0.07126096406869613, 0.03729108472544075, 0.022255617268456075, 0.04201934078492903, 0.0833854004007896, 0.03729108472544075, 0.0, 0.02942150573984955, 0.055127692677999864, 0.03473110997362451, 0.053851648071345036, 0.08125, 0.08254733490549529, 0.07400380057807843, 0.04731873307686925, 0.057363969527918834, 0.03745831015942924, 0.07267220926874317, 0.020501524333570907, 0.06105837370909907, 0.045500686808003246]
# [0.0642748006609122, 0.06309714732061981, 0.022946949688357275, 0.06670832032063168, 0.10056092680559384, 0.06309714732061981, 0.02942150573984955, 0.0, 0.06933839124179332, 0.05199158585771356, 0.05692648768367851, 0.10958016471971559, 0.1106867765363144, 0.10338792240876109, 0.07509369147937796, 0.06490377492873586, 0.023048861143232218, 0.09951444618747571, 0.04244481711587412, 0.07250000000000001, 0.0748853290037508]
# [0.04751644452187053, 0.033000946956110215, 0.04640177798317646, 0.08288734825050202, 0.1288470508005519, 0.033000946956110215, 0.055127692677999864, 0.06933839124179332, 0.0, 0.08610495049647263, 0.0242706097986845, 0.0676618430136218, 0.06719840027857807, 0.07603453162872775, 0.07766112283504534, 0.01505199322349037, 0.05392413652530749, 0.051795873387751656, 0.07178527007680616, 0.11303345743628301, 0.05836308764964376]
# [0.10578575045817844, 0.05908151149048237, 0.05602733707753743, 0.02069118169655856, 0.04952903189039738, 0.05908151149048237, 0.03473110997362451, 0.05199158585771356, 0.08610495049647263, 0.0, 0.08835298523536146, 0.0885031779090446, 0.09052796529249954, 0.07341023430013012, 0.03502231431530475, 0.0909154827298409, 0.06903350635742038, 0.08609587678861282, 0.014630874888399533, 0.02698379143115363, 0.04995310300672022]
# [0.024558603380485624, 0.048637691145859294, 0.036336104634371584, 0.09077788827682653, 0.13556594336336839, 0.048637691145859294, 0.053851648071345036, 0.05692648768367851, 0.0242706097986845, 0.08835298523536146, 0.0, 0.09042434683203412, 0.09021675287883066, 0.09605499726719065, 0.08938155570362379, 0.010752906583803285, 0.03644344934278313, 0.07504165509901818, 0.07379236071572721, 0.114904851942814, 0.07396156096243509]
# [0.11473474844178637, 0.047909419741842, 0.0917196816392207, 0.07103036322587686, 0.10625, 0.047909419741842, 0.08125, 0.10958016471971559, 0.0676618430136218, 0.0885031779090446, 0.09042434683203412, 0.0, 0.0025, 0.021286732957408006, 0.05648561763847502, 0.0826230143483037, 0.10671955069245749, 0.01625, 0.08131727983645297, 0.10791344911548328, 0.038931028755993594]
# [0.11443475215160823, 0.04862162584694181, 0.0925, 0.07323976037645127, 0.10872126057032268, 0.04862162584694181, 0.08254733490549529, 0.1106867765363144, 0.06719840027857807, 0.09052796529249954, 0.09021675287883066, 0.0025, 0.0, 0.02378287198805056, 0.0587632963677158, 0.08220591523728692, 0.10733271868354029, 0.015461646096066229, 0.08310385069297331, 0.11017741374710155, 0.04081206929328628]
# [0.12057803489856685, 0.048299197715904144, 0.08896979824637123, 0.05409771252095601, 0.08555882479323801, 0.048299197715904144, 0.07400380057807843, 0.10338792240876109, 0.07603453162872775, 0.07341023430013012, 0.09605499726719065, 0.021286732957408006, 0.02378287198805056, 0.0, 0.03905124837953327, 0.0901127765635928, 0.10506694294591426, 0.031942330847951596, 0.06903350635742038, 0.08983491804415475, 0.02850438562747845]
# [0.11175447418336323, 0.0448086208223373, 0.06803032412093889, 0.01505199322349037, 0.05427073336523103, 0.0448086208223373, 0.04731873307686925, 0.07509369147937796, 0.07766112283504534, 0.03502231431530475, 0.08938155570362379, 0.05648561763847502, 0.0587632963677158, 0.03905124837953327, 0.0, 0.08772293029761376, 0.08419657059524456, 0.05816195062065921, 0.03432382554436496, 0.05143260152860246, 0.022638462845343543]
# [0.0325, 0.04451123453691215, 0.042957100693598954, 0.09089829481348922, 0.13647344063956182, 0.04451123453691215, 0.057363969527918834, 0.06490377492873586, 0.01505199322349037, 0.0909154827298409, 0.010752906583803285, 0.0826230143483037, 0.08220591523728692, 0.0901127765635928, 0.08772293029761376, 0.0, 0.04589389937671455, 0.0668253320231183, 0.07629097259833564, 0.11781871667948181, 0.07027846398435299]
# [0.04123105625617661, 0.0588430114796991, 0.016441183047457383, 0.07941190087134295, 0.11855905701379377, 0.0588430114796991, 0.03745831015942924, 0.023048861143232218, 0.05392413652530749, 0.06903350635742038, 0.03644344934278313, 0.10671955069245749, 0.10733271868354029, 0.10506694294591426, 0.08419657059524456, 0.04589389937671455, 0.0, 0.09409104633279407, 0.05652709527297507, 0.09253377761660873, 0.07759067276419249]
# [0.09913690029449176, 0.03644344934278313, 0.07997069775861657, 0.07126096406869613, 0.11125702225028315, 0.03644344934278313, 0.07267220926874317, 0.09951444618747571, 0.051795873387751656, 0.08609587678861282, 0.07504165509901818, 0.01625, 0.015461646096066229, 0.031942330847951596, 0.05816195062065921, 0.0668253320231183, 0.09409104633279407, 0.0, 0.07661796460360978, 0.10835416466384669, 0.03676360292463186]
# [0.09176226076116477, 0.04638493828819869, 0.042426406871192854, 0.0242706097986845, 0.0629111476608081, 0.04638493828819869, 0.020501524333570907, 0.04244481711587412, 0.07178527007680616, 0.014630874888399533, 0.07379236071572721, 0.08131727983645297, 0.08310385069297331, 0.06903350635742038, 0.03432382554436496, 0.07629097259833564, 0.05652709527297507, 0.07661796460360978, 0.0, 0.041551925346486655, 0.04246321937865758]
# [0.1311964176340193, 0.085, 0.08125, 0.037165171868296265, 0.030923292192132457, 0.085, 0.06105837370909907, 0.07250000000000001, 0.11303345743628301, 0.02698379143115363, 0.114904851942814, 0.10791344911548328, 0.11017741374710155, 0.08983491804415475, 0.05143260152860246, 0.11781871667948181, 0.09253377761660873, 0.10835416466384669, 0.041551925346486655, 0.0, 0.07160001745809844]
# [0.0978279740156158, 0.02576941016011038, 0.06126275377421423, 0.03457329171484833, 0.07690294207636013, 0.02576941016011038, 0.045500686808003246, 0.0748853290037508, 0.05836308764964376, 0.04995310300672022, 0.07396156096243509, 0.038931028755993594, 0.04081206929328628, 0.02850438562747845, 0.022638462845343543, 0.07027846398435299, 0.07759067276419249, 0.03676360292463186, 0.04246321937865758, 0.07160001745809844, 0.0]
# Individu 1 -  Consommation d'énergie : 1.3095394590101814, Fitness Score : 0.7636272378961779
# Individu 2 -  Consommation d'énergie : 1.1801493496461242, Fitness Score : 0.8473503801021937
# Individu 3 -  Consommation d'énergie : 1.2567587137345797, Fitness Score : 0.7956976856984771
# Individu 4 -  Consommation d'énergie : 1.1174661406013036, Fitness Score : 0.8948817003635604
# Individu 5 -  Consommation d'énergie : 1.1430869904186305, Fitness Score : 0.8748240583455262
# Individu 6 -  Consommation d'énergie : 1.0779554526561996, Fitness Score : 0.9276821203843731
# Individu 7 -  Consommation d'énergie : 1.076349476364626, Fitness Score : 0.929066276296713
# Individu 8 -  Consommation d'énergie : 1.1766623061529053, Fitness Score : 0.8498615063734791
# Individu 9 -  Consommation d'énergie : 1.194195699971909, Fitness Score : 0.8373836884721013
# Individu 10 -  Consommation d'énergie : 1.116066647187621, Fitness Score : 0.8960038385878678
# Individu 11 -  Consommation d'énergie : 1.2843713061371118, Fitness Score : 0.7785910470139746
# Individu 12 -  Consommation d'énergie : 1.242871137142507, Fitness Score : 0.8045886416665097
# Individu 13 -  Consommation d'énergie : 1.2000440508487271, Fitness Score : 0.8333027435890819
# Individu 14 -  Consommation d'énergie : 1.239055535624316, Fitness Score : 0.8070663269311295
# Individu 15 -  Consommation d'énergie : 1.235419043893392, Fitness Score : 0.8094419500354513
# Individu 16 -  Consommation d'énergie : 1.1889760816777755, Fitness Score : 0.8410598122284264
# Individu 17 -  Consommation d'énergie : 1.093367673466436, Fitness Score : 0.9146054198123298
# Individu 18 -  Consommation d'énergie : 1.2467820109325614, Fitness Score : 0.8020648286800556
# Individu 19 -  Consommation d'énergie : 1.2704195418234858, Fitness Score : 0.7871415442528997
# Individu 20 -  Consommation d'énergie : 1.2268645650483487, Fitness Score : 0.8150858933321558
# Individu 21 -  Consommation d'énergie : 1.262000187670936, Fitness Score : 0.7923929091052941
# Individu 22 -  Consommation d'énergie : 1.2993567922520755, Fitness Score : 0.7696115539341405
# Individu 23 -  Consommation d'énergie : 1.1096822990029214, Fitness Score : 0.9011588279803383
# Individu 24 -  Consommation d'énergie : 1.2235914570754753, Fitness Score : 0.8172662486465174
# Individu 25 -  Consommation d'énergie : 1.2473240405788208, Fitness Score : 0.8017162882036251
# Individu 26 -  Consommation d'énergie : 1.1849501989736477, Fitness Score : 0.8439173231635865
# Individu 27 -  Consommation d'énergie : 1.0539945707711884, Fitness Score : 0.9487714906048504
# Individu 28 -  Consommation d'énergie : 1.231507271141033, Fitness Score : 0.8120130700271596
# Individu 29 -  Consommation d'énergie : 1.163540043854337, Fitness Score : 0.859446140493287
# Individu 30 -  Consommation d'énergie : 1.0550108807661265, Fitness Score : 0.9478575228284103
# Individu 31 -  Consommation d'énergie : 1.2821457311712792, Fitness Score : 0.7799425413883877
# Individu 32 -  Consommation d'énergie : 1.2908194655986223, Fitness Score : 0.7747016733561934
# Individu 33 -  Consommation d'énergie : 1.1452818967807818, Fitness Score : 0.8731474781980334
# Individu 34 -  Consommation d'énergie : 0.9645683898572486, Fitness Score : 1.03673312386693
# Individu 35 -  Consommation d'énergie : 1.4207058976249431, Fitness Score : 0.7038754478824535
# Individu 36 -  Consommation d'énergie : 1.2139570998931781, Fitness Score : 0.8237523386024059
# Individu 37 -  Consommation d'énergie : 1.2357175756959655, Fitness Score : 0.809246400365223
# Individu 38 -  Consommation d'énergie : 1.1915357770600707, Fitness Score : 0.8392530205575065
# Individu 39 -  Consommation d'énergie : 0.8902483468971153, Fitness Score : 1.123282063353911
# Individu 40 -  Consommation d'énergie : 1.2605547630733518, Fitness Score : 0.7933015123927701
# Individu 41 -  Consommation d'énergie : 1.248083887061907, Fitness Score : 0.8012281949685953
# Individu 42 -  Consommation d'énergie : 1.2625504453658236, Fitness Score : 0.7920475602939179
# Individu 43 -  Consommation d'énergie : 1.019655574971427, Fitness Score : 0.980723319271826
# Individu 44 -  Consommation d'énergie : 1.3964440645629226, Fitness Score : 0.7161045869123251
# Individu 45 -  Consommation d'énergie : 1.3697892793204216, Fitness Score : 0.7300392951652527
# Individu 46 -  Consommation d'énergie : 1.3341974165403925, Fitness Score : 0.74951426798069
# Individu 47 -  Consommation d'énergie : 1.2070230400509288, Fitness Score : 0.8284845995630757
# Individu 48 -  Consommation d'énergie : 1.3910977002971483, Fitness Score : 0.7188567702947053
# Individu 49 -  Consommation d'énergie : 1.204342495059193, Fitness Score : 0.8303285851844415
# Individu 50 -  Consommation d'énergie : 1.1757577811505349, Fitness Score : 0.8505153153411007
# Parent: [12, 15, 17, 1, 8, 16, 7, 11, 13, 18, 4, 9, 10, 5, 19, 6, 20, 3, 14, 2]
# Parent: [14, 4, 17, 16, 19, 11, 18, 3, 9, 13, 15, 12, 2, 5, 20, 6, 10, 8, 1, 7]
# Temps d'exécution de crossover: 0.06842613220214844 millisecondes
# child: [12, 15, 17, 1, 8, 16, 7, 11, 13, 18, 4, 14, 19, 3, 9, 2, 5, 20, 6, 10]
# child: [14, 4, 17, 12, 15, 1, 8, 16, 7, 11, 13, 18, 9, 10, 5, 19, 6, 20, 3, 2]
# child mutate: [12, 15, 17, 1, 8, 16, 7, 11, 13, 18, 4, 14, 19, 3, 9, 2, 5, 20, 6, 10]
# child mutate: [14, 4, 17, 12, 15, 1, 8, 16, 7, 11, 13, 18, 9, 10, 5, 19, 6, 20, 3, 2]

# %% [markdown]
# Exécution de l'algorithme génétique (trouver le meilleur individu avec leur score  )

# %%
import random

def execute_genetic_algorithm(clients, population_size, demands, capacity, num_parents, crossover_rate, mutation_rate, num_generations,  speed, consumption_rate):


    # Générer la population initiale
    population = generate_population(clients, population_size)

    # Calculer la matrice des distances
    distance_matrix = calculate_distance_matrix(client_coordinates)

    # Calculer la matrice de consommation d'énergie
    energy_matrix = calculate_energy_consumption(speed, consumption_rate, distance_matrix)

    # Boucle sur le nombre de générations
    for generation in range(num_generations):
        # Évaluer la population
        energies, fitness_scores = evaluate_population(client_coordinates, speed, consumption_rate, population)

        # Sélectionner les parents
        parents = select_parents(population, num_parents)

        # Effectuer le croisement
        children = crossover(parents, crossover_rate)

        # Effectuer la mutation
        mutated_children = mutation(children, mutation_rate)

        # Remplacer la population par les enfants mutés
        population = mutated_children

    # Évaluer la population finale
    energies, fitness_scores = evaluate_population(client_coordinates, speed, consumption_rate, population)

    # Trouver l'indice de l'individu avec le score de fitness minimum parmi les enfants mutés
    best_index = fitness_scores.index(min(fitness_scores))

    # Renvoyer le meilleur individu parmi les enfants mutés
    return population[best_index]

# %% [markdown]
# Affichage du meilleur individu

# %%
best_individual = execute_genetic_algorithm(clients, population_size, demands, capacity, num_parents, crossover_rate, mutation_rate, num_generations, speed, consumption_rate)
print("Meilleur individu:", best_individual)
# Out:
# Temps d'exécution de crossover: 0.05364418029785156 millisecondes
# Temps d'exécution de crossover: 0.029802322387695312 millisecondes
# Temps d'exécution de crossover: 0.02384185791015625 millisecondes
# Temps d'exécution de crossover: 0.05340576171875 millisecondes
# Temps d'exécution de crossover: 0.06580352783203125 millisecondes
# Temps d'exécution de crossover: 0.06198883056640625 millisecondes
# Temps d'exécution de crossover: 0.1595020294189453 millisecondes
# Temps d'exécution de crossover: 0.15783309936523438 millisecondes
# Temps d'exécution de crossover: 0.024080276489257812 millisecondes
# Temps d'exécution de crossover: 0.043392181396484375 millisecondes
# Temps d'exécution de crossover: 0.023365020751953125 millisecondes
# Temps d'exécution de crossover: 0.04100799560546875 millisecondes
# Temps d'exécution de crossover: 0.028371810913085938 millisecondes
# Temps d'exécution de crossover: 0.053882598876953125 millisecondes
# Temps d'exécution de crossover: 0.039577484130859375 millisecondes
# Temps d'exécution de crossover: 0.05602836608886719 millisecondes
# Temps d'exécution de crossover: 0.16427040100097656 millisecondes
# Temps d'exécution de crossover: 0.14090538024902344 millisecondes
# Temps d'exécution de crossover: 0.029325485229492188 millisecondes
# Temps d'exécution de crossover: 0.03838539123535156 millisecondes
# Temps d'exécution de crossover: 0.03910064697265625 millisecondes
# Temps d'exécution de crossover: 0.05364418029785156 millisecondes
# Temps d'exécution de crossover: 32.71222114562988 millisecondes
# Temps d'exécution de crossover: 0.04315376281738281 millisecondes
# Temps d'exécution de crossover: 0.03910064697265625 millisecondes
# Temps d'exécution de crossover: 0.027894973754882812 millisecondes
# Temps d'exécution de crossover: 0.025987625122070312 millisecondes
# Temps d'exécution de crossover: 0.024318695068359375 millisecondes
# Temps d'exécution de crossover: 0.025987625122070312 millisecondes
# Temps d'exécution de crossover: 0.06175041198730469 millisecondes
# Temps d'exécution de crossover: 0.034809112548828125 millisecondes
# Temps d'exécution de crossover: 0.028371810913085938 millisecondes
# Temps d'exécution de crossover: 0.043392181396484375 millisecondes
# Temps d'exécution de crossover: 0.07510185241699219 millisecondes
# Temps d'exécution de crossover: 0.030755996704101562 millisecondes
# Temps d'exécution de crossover: 0.04029273986816406 millisecondes
# Temps d'exécution de crossover: 0.025987625122070312 millisecondes
# Temps d'exécution de crossover: 0.049591064453125 millisecondes
# Temps d'exécution de crossover: 0.04172325134277344 millisecondes
# Temps d'exécution de crossover: 0.04029273986816406 millisecondes
# Temps d'exécution de crossover: 0.022411346435546875 millisecondes
# Temps d'exécution de crossover: 0.04673004150390625 millisecondes
# Temps d'exécution de crossover: 0.050067901611328125 millisecondes
# Temps d'exécution de crossover: 0.04291534423828125 millisecondes
# Temps d'exécution de crossover: 0.04696846008300781 millisecondes
# Temps d'exécution de crossover: 0.042438507080078125 millisecondes
# Temps d'exécution de crossover: 0.04172325134277344 millisecondes
# Temps d'exécution de crossover: 0.04553794860839844 millisecondes
# Temps d'exécution de crossover: 0.04100799560546875 millisecondes
# Temps d'exécution de crossover: 0.025272369384765625 millisecondes
# Temps d'exécution de crossover: 0.0030994415283203125 millisecondes
# Temps d'exécution de crossover: 0.06389617919921875 millisecondes
# Temps d'exécution de crossover: 0.0629425048828125 millisecondes
# Temps d'exécution de crossover: 0.04267692565917969 millisecondes
# Temps d'exécution de crossover: 0.03647804260253906 millisecondes
# Temps d'exécution de crossover: 0.023365020751953125 millisecondes
# Temps d'exécution de crossover: 0.04029273986816406 millisecondes
# Temps d'exécution de crossover: 0.024080276489257812 millisecondes
# Temps d'exécution de crossover: 0.05340576171875 millisecondes
# Temps d'exécution de crossover: 0.024318695068359375 millisecondes
# Temps d'exécution de crossover: 0.022172927856445312 millisecondes
# Temps d'exécution de crossover: 0.0247955322265625 millisecondes
# Temps d'exécution de crossover: 0.023603439331054688 millisecondes
# Temps d'exécution de crossover: 0.04172325134277344 millisecondes
# Temps d'exécution de crossover: 0.046253204345703125 millisecondes
# Temps d'exécution de crossover: 0.02384185791015625 millisecondes
# Temps d'exécution de crossover: 0.03647804260253906 millisecondes
# Temps d'exécution de crossover: 0.038623809814453125 millisecondes
# Temps d'exécution de crossover: 0.024080276489257812 millisecondes
# Temps d'exécution de crossover: 0.041484832763671875 millisecondes
# Temps d'exécution de crossover: 0.04220008850097656 millisecondes
# Temps d'exécution de crossover: 0.06937980651855469 millisecondes
# Temps d'exécution de crossover: 0.04124641418457031 millisecondes
# Temps d'exécution de crossover: 0.025987625122070312 millisecondes
# Temps d'exécution de crossover: 0.0400543212890625 millisecondes
# Temps d'exécution de crossover: 0.03838539123535156 millisecondes
# Temps d'exécution de crossover: 0.030994415283203125 millisecondes
# Temps d'exécution de crossover: 0.0400543212890625 millisecondes
# Temps d'exécution de crossover: 0.03790855407714844 millisecondes
# Temps d'exécution de crossover: 0.03814697265625 millisecondes
# Temps d'exécution de crossover: 0.034332275390625 millisecondes
# Temps d'exécution de crossover: 0.03647804260253906 millisecondes
# Temps d'exécution de crossover: 0.020503997802734375 millisecondes
# Temps d'exécution de crossover: 0.023365020751953125 millisecondes
# Temps d'exécution de crossover: 0.05340576171875 millisecondes
# Temps d'exécution de crossover: 0.038623809814453125 millisecondes
# Temps d'exécution de crossover: 0.023603439331054688 millisecondes
# Temps d'exécution de crossover: 0.03838539123535156 millisecondes
# Temps d'exécution de crossover: 0.03361701965332031 millisecondes
# Temps d'exécution de crossover: 0.05364418029785156 millisecondes
# Temps d'exécution de crossover: 0.025033950805664062 millisecondes
# Temps d'exécution de crossover: 0.03600120544433594 millisecondes
# Temps d'exécution de crossover: 0.025987625122070312 millisecondes
# Temps d'exécution de crossover: 0.08273124694824219 millisecondes
# Temps d'exécution de crossover: 0.04029273986816406 millisecondes
# Temps d'exécution de crossover: 0.044345855712890625 millisecondes
# Temps d'exécution de crossover: 0.03933906555175781 millisecondes
# Temps d'exécution de crossover: 0.038623809814453125 millisecondes
# Temps d'exécution de crossover: 0.020265579223632812 millisecondes
# Temps d'exécution de crossover: 0.03600120544433594 millisecondes
# Meilleur individu: [6, 10, 19, 20, 17, 12, 7, 3, 4, 2, 13, 1, 8, 14, 15, 16, 11, 18, 5, 9]

# %% [markdown]
# Fonction de découdage du meilleur individu retourner par l'algorithme génétique et qui donne les routes avec leur distance, leur consommation d'enrgie

# %%
def decode_best_individual(best_individual, demands, capacity, distance_matrix, energy_matrix, k):
    routes = []
    current_route = [0]  # Commence chaque route par le dépôt
    current_demand = 0
    current_distance = 0
    current_energy_consumption = 0

    # Initialise la liste des clients non visités
    unvisited_clients = set(best_individual)

    # Parcours les clients du meilleur individu dans l'ordre
    for client in best_individual:
        # Si le client est déjà visité ou s'il s'agit du dépôt, passe au suivant
        if client == 0 or client not in unvisited_clients:
            continue

        # Si ajouter le client ne viole pas les contraintes
        if current_demand + demands[client - 1] <= capacity and len(current_route) <= k + 1:
            current_route.append(client)
            current_demand += demands[client - 1]
            current_distance += distance_matrix[current_route[-2]][client]
            current_energy_consumption += energy_matrix[current_route[-2]][client]
            unvisited_clients.remove(client)
        else:
            # Termine la route actuelle et démarre une nouvelle route
            current_route.append(0)  # Termine la route actuelle par le dépôt
            current_distance += distance_matrix[current_route[-2]][0]
            current_energy_consumption += energy_matrix[current_route[-2]][0]
            routes.append((current_route, current_distance, current_energy_consumption))
            current_route = [0, client]  # Démarre une nouvelle route avec le dépôt et le client
            current_demand = demands[client - 1]
            current_distance = distance_matrix[0][client]
            current_energy_consumption = energy_matrix[0][client]
            unvisited_clients.remove(client)

    # Termine la dernière route
    current_route.append(0)  # Termine la dernière route par le dépôt
    current_distance += distance_matrix[current_route[-2]][0]
    current_energy_consumption += energy_matrix[current_route[-2]][0]
    routes.append((current_route, current_distance, current_energy_consumption))

    return routes

# %% [markdown]
# Affichage des routes

# %%
routes = decode_best_individual(best_individual, demands, capacity, distance_matrix, energy_matrix, k)
total_distance = 0
total_energy_consumption = 0

for route, distance, energy_consumption in routes:
    print("Route:", route)
    print("Distance:", distance)
    print("Energy Consumption:", energy_consumption)
    print()

    total_distance += distance
    total_energy_consumption += energy_consumption

print("Total Distance:", total_distance)
print("Total Energy Consumption:", total_energy_consumption)
# Out:
# Route: [0, 6, 10, 19, 20, 17, 0]
# Distance: 358.01438780806177
# Energy Consumption: 0.4475179847600772
#
# Route: [0, 12, 7, 3, 4, 2, 0]
# Distance: 394.41586436451564
# Energy Consumption: 0.4930198304556445
#
# Route: [0, 13, 1, 8, 14, 15, 0]
# Distance: 319.8097861625922
# Energy Consumption: 0.3997622327032403
#
# Route: [0, 16, 11, 18, 5, 9, 0]
# Distance: 352.41606961755724
# Energy Consumption: 0.44052008702194656
#
# Total Distance: 1424.6561079527269
# Total Energy Consumption: 1.7808201349409087

# %% [markdown]
# plot des routes

# %%
import matplotlib.pyplot as plt

def plot_routes(routes, distance_matrix):
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']  # Liste de couleurs prédéfinies

    for i, (route, _, _) in enumerate(routes):
        x_coords = []
        y_coords = []
        for client in route[:]:
            x = client_coordinates[client][0]
            y = client_coordinates[client][1]
            x_coords.append(x)
            y_coords.append(y)
            plt.plot(x, y, marker='o', color=colors[i % len(colors)])  # Attribution de la couleur

            plt.text(x, y, str(client), verticalalignment='bottom', horizontalalignment='right')

        plt.plot(x_coords + [x_coords[0]], y_coords + [y_coords[0]], color=colors[i % len(colors)])

    # Affichage du dépôt
    depot_x = client_coordinates[0][0]
    depot_y = client_coordinates[0][1]
    plt.plot(depot_x, depot_y, marker='o', color='red', label='Dépôt')
    plt.text(depot_x, depot_y, 'Dépôt', verticalalignment='bottom', horizontalalignment='right')

    plt.xlabel('Coordonnée X')
    plt.ylabel('Coordonnée Y')
    plt.title('Routes')
    plt.legend()
    plt.grid(True)
    plt.show()
plot_routes(routes, distance_matrix)
